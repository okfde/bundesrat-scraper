# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json
import os

# %%
import scraper_thueringen

# %%
USE_CACHE = True

# %%
if USE_CACHE:
    os.makedirs('./_cache', exist_ok=True)

# %%
with open('../bundesrat/sessions.json') as f:
    sessions = json.load(f)
len(sessions)
# Out:
# 91

# %%
FILENAME = 'session_tops.json'
if os.path.exists(FILENAME):
    with open(FILENAME) as f:
        session_tops = json.load(f)
else:
    session_tops = {}

# %%
for session in sessions:
    num = session['number']
    if str(num) in session_tops:
        continue
    print('\nLoading tops of: %s' % num)
    
    #Need class for later init, don't have all params by now
    result = scraper_thueringen.MainExtractorMethod(scraper_thueringen.TextExtractorHolder).get_session(session)
    if result is None:
        continue
    session_tops[str(num)] = result
    with open(FILENAME, 'w') as f:
        json.dump(session_tops, f)
        
print('Total sessions:', len(session_tops))
# Out:
# Loading tops of: 985
#
# Loading tops of: 986
#
# Loading tops of: 987
#
# Loading tops of: 988
#
# Loading tops of: 989
#
# Loading tops of: 990
#
# Loading tops of: 991
#
# Loading tops of: 992
#
# Loading tops of: 985
#
# Loading tops of: 984
#
# Loading tops of: 983
#
# Loading tops of: 982
#
# Loading tops of: 981
#
# Loading tops of: 980
#
# Loading tops of: 979
#
# Loading tops of: 978
#
# Loading tops of: 977
#
# Loading tops of: 976
#
# Loading tops of: 975
#
# Loading tops of: 974
#
# Loading tops of: 973
#
# Loading tops of: 972
#
# Loading tops of: 971
#
# Loading tops of: 970
#
# Loading tops of: 969
#
# Loading tops of: 968
#
# Loading tops of: 967
#
# Loading tops of: 966
#
# Loading tops of: 965
#
# Loading tops of: 964
#
# Loading tops of: 963
#
# Loading tops of: 962
#
# Loading tops of: 961
#
# Loading tops of: 960
#
# Loading tops of: 959
#
# Loading tops of: 958
#
# Loading tops of: 957
#
# Loading tops of: 956
#
# Loading tops of: 955
#
# Loading tops of: 954
#
# Loading tops of: 953
#
# Loading tops of: 952
#
# Loading tops of: 951
#
# Loading tops of: 950
#
# Loading tops of: 949
#
# Loading tops of: 948
#
# Loading tops of: 947
#
# Loading tops of: 946
#
# Loading tops of: 945
#
# Loading tops of: 944
#
# Loading tops of: 943
#
# Loading tops of: 942
#
# Loading tops of: 941
#
# Loading tops of: 940
#
# Loading tops of: 939
#
# Loading tops of: 938
#
# Loading tops of: 937
#
# Loading tops of: 936
#
# Loading tops of: 935
#
# Loading tops of: 934
#
# Loading tops of: 933
#
# Loading tops of: 932
#
# Loading tops of: 931
#
# Loading tops of: 930
#
# Loading tops of: 929
#
# Loading tops of: 928
#
# Loading tops of: 927
#
# Loading tops of: 926
#
# Loading tops of: 925
#
# Loading tops of: 924
#
# Loading tops of: 923
#
# Loading tops of: 922
#
# Loading tops of: 921
#
# Loading tops of: 920
#
# Loading tops of: 919
#
# Loading tops of: 918
#
# Loading tops of: 917
#
# Loading tops of: 916
#
# Loading tops of: 915
#
# Loading tops of: 914
#
# Loading tops of: 913
#
# Loading tops of: 912
#
# Loading tops of: 911
#
# Loading tops of: 910
# Total sessions: 10
